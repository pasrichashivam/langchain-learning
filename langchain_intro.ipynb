# %% [markdown]
# ## Langchain
#
# ### Langchain Journey
# <img src="notebook_assets/LangchainJourney.png" width="900" height="500">
# <img src="notebook_assets/langchain_vs_langraph_vs_deepagents.png" width="900" height="500">
