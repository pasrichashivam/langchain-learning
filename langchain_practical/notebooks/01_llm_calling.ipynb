# %%
import os
from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model

# %%
load_dotenv()
GROQ_API_KEY = os.getenv("GROQ_API_KEY")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### Models / LLMs
# LLMs are powerful AI tools that can interpret and generate text like humans.
# In addition to text generation, many models support:
# * Tool calling - calling external tools (like databases queries or API calls) and use results in their responses.
# * Structured output - where the model’s response is constrained to follow a defined format.
# * Multimodality - process and return data other than text, such as images, audio, and video.
# * Reasoning - models perform multi-step reasoning to arrive at a conclusion.
#
# Models are the reasoning engine of agents. They drive the agent’s decision-making process, determining which tools to call, how to interpret results, and when to provide a final answer.
# The quality and capabilities of the model you choose directly impact your agent’s baseline reliability and performance. Different models excel at different tasks - some are better at following complex instructions, others at structured reasoning, and some support larger context windows for handling more information.
#
# <img src="../../notebook_assets/langchain_remote_for_llms.png" width="1200" height="600">
#
# <img src="../../notebook_assets/model_providers_0.png" width="500" height="500">
# <img src="../../notebook_assets/model_providers_1.png" width="500" height="500">

# %%
openai_model = init_chat_model(
    model="openai:gpt-5-nano"
)

# %%
response = openai_model.invoke("What's Karnal city in india famous for?")
print(response.content)
# Out:
# Karnal is a city in Haryana, India. It’s famous for:
#
# - The Treaty of Karnal (1739) between Nadir Shah and the Mughal emperor Muhammad Shah, a key historical event.
# - Being a major agricultural and dairy research hub, home to the National Dairy Research Institute (NDRI) and other ICAR institutes.
# - Karnal Lake, a popular local landmark and recreation spot.
# - Its significance in grain farming and agricultural markets in the region.

# %%
print("Text \t\t:", response.content)
print("content_blocks\t: ", response.content_blocks)
print("Response ID\t",response.id)
print("Tool Calls: \t", response.tool_calls)
print("Usage Metadata:\t ", response.usage_metadata)
# Out:
# Text 		: Karnal is a city in Haryana, India. It’s famous for:
#
# - The Treaty of Karnal (1739) between Nadir Shah and the Mughal emperor Muhammad Shah, a key historical event.
# - Being a major agricultural and dairy research hub, home to the National Dairy Research Institute (NDRI) and other ICAR institutes.
# - Karnal Lake, a popular local landmark and recreation spot.
# - Its significance in grain farming and agricultural markets in the region.
# content_blocks	:  [{'type': 'text', 'text': 'Karnal is a city in Haryana, India. It’s famous for:\n\n- The Treaty of Karnal (1739) between Nadir Shah and the Mughal emperor Muhammad Shah, a key historical event.\n- Being a major agricultural and dairy research hub, home to the National Dairy Research Institute (NDRI) and other ICAR institutes.\n- Karnal Lake, a popular local landmark and recreation spot.\n- Its significance in grain farming and agricultural markets in the region.'}]
# ...

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content='You are comedian, answer everything in funny way'),
    HumanMessage(content='What is a capital of France')
]
response = openai_model.invoke(messages)

# %%
response_json = {
  "content": "Paris — the capital of France. Also the city where croissants are basically a national sport, and the Eiffel Tower doubles as the world’s tallest selfie stick. Need directions? Just follow the croissants; they always know the way.",
  "additional_kwargs": {
    "refusal": None
  },
  "response_metadata": {
    "token_usage": {
      "completion_tokens": 632,
      "prompt_tokens": 25,
      "total_tokens": 657,
      "completion_tokens_details": {
        "accepted_prediction_tokens": 0,
        "audio_tokens": 0,
        "reasoning_tokens": 576,
        "rejected_prediction_tokens": 0
      },
      "prompt_tokens_details": {
        "audio_tokens": 0,
        "cache_write_tokens": None,
        "cached_tokens": 0
      }
    },
    "model_provider": "openai",
    "model_name": "gpt-5-nano-2025-08-07",
    "system_fingerprint": None,
    "id": "chatcmpl-E2rRb9EUtVE204MfAlBVARH1wGBaF",
    "service_tier": "default",
    "finish_reason": "stop",
    "logprobs": None
  },
  "id": "lc_run--019f7398-7fe8-78a3-ba5a-43626eafb32c-0",
  "tool_calls": [],
  "invalid_tool_calls": [],
  "usage_metadata": {
    "input_tokens": 25,
    "output_tokens": 632,
    "total_tokens": 657,
    "input_token_details": {
      "audio": 0,
      "cache_read": 0
    },
    "output_token_details": {
      "audio": 0,
      "reasoning": 576
    }
  }
}

# %% [markdown]
# * Its very difficult to call different models from different providers as th

# %% [markdown]
# ### Model Parameters
