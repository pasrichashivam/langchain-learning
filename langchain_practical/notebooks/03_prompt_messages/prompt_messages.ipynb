# %% [markdown]
# <img src="../../../assets/prompt_messages.png" width="900" height="400">

# %%
import os

from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model="gpt-5-nano")
